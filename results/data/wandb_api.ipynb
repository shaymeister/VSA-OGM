# %%
import pandas as pd 
import wandb
import json

api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("ssnyde9-george-mason-university/VSA-OGM Parameter Ablation - Ablation Sparse - V2")

count = 0

config_list = []
for run in runs: 
    if count % 10 == 0:
        print(f"Run {count} of {len(runs)}")
    count += 1

    run_config = {}
    run_config["test_nll"] = run.summary["test_nll"]
    run_config["test_auc"] = run.summary["test_auc"]

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    mapping_config = run.config["mapping"]
    for key, value in mapping_config.items():
            if isinstance(value, dict):
                for k, v in value.items():
                    run_config[f"{key}_{k}"] = v
            else:
                run_config[key] = value

    config_list.append(run_config)

runs_df = pd.DataFrame(config_list)

runs_df.to_csv("exp2_ablation_sparse_v2.csv")
# Out:
# Run 0 of 768
# Run 10 of 768
# Run 20 of 768
# Run 30 of 768
# Run 40 of 768
# Run 50 of 768
# Run 60 of 768
# Run 70 of 768
# Run 80 of 768
# Run 90 of 768
# Run 100 of 768
# Run 110 of 768
# Run 120 of 768
# Run 130 of 768
# Run 140 of 768
# Run 150 of 768
# Run 160 of 768
# Run 170 of 768
# Run 180 of 768
# Run 190 of 768
# Run 200 of 768
# Run 210 of 768
# Run 220 of 768
# Run 230 of 768
# Run 240 of 768
# Run 250 of 768
# Run 260 of 768
# Run 270 of 768
# Run 280 of 768
# Run 290 of 768
# Run 300 of 768
# Run 310 of 768
# Run 320 of 768
# Run 330 of 768
# Run 340 of 768
# Run 350 of 768
# Run 360 of 768
# Run 370 of 768
# Run 380 of 768
# Run 390 of 768
# Run 400 of 768
# Run 410 of 768
# Run 420 of 768
# Run 430 of 768
# Run 440 of 768
# Run 450 of 768
# Run 460 of 768
# Run 470 of 768
# Run 480 of 768
# Run 490 of 768
# Run 500 of 768
# Run 510 of 768
# Run 520 of 768
# Run 530 of 768
# Run 540 of 768
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# Run 550 of 768
# Run 560 of 768
# Run 570 of 768
# Run 580 of 768
# Run 590 of 768
# Run 600 of 768
# Run 610 of 768
# Run 620 of 768
# Run 630 of 768
# Run 640 of 768
# Run 650 of 768
# Run 660 of 768
# Run 670 of 768
# Run 680 of 768
# Run 690 of 768
# Run 700 of 768
# Run 710 of 768
# Run 720 of 768
# Run 730 of 768
# Run 740 of 768
# Run 750 of 768
# Run 760 of 768
